# %%
import pandas as pd
import numpy as np
import random
import time
import matplotlib.pyplot as plt

# %%
from sklearn.utils import shuffle
from river import stream, base, compose, preprocessing, metrics, drift, tree
from datetime import datetime
from collections import Counter

# %%
df = pd.read_csv('CICIoMT2024/Test.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1612117 entries, 0 to 1612116
# Data columns (total 46 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   Header_Length    1612117 non-null  float64
#  1   Protocol Type    1612117 non-null  float64
#  2   Duration         1612117 non-null  float64
#  3   Rate             1612117 non-null  float64
#  4   Srate            1612117 non-null  float64
#  5   Drate            1612117 non-null  float64
#  6   fin_flag_number  1612117 non-null  float64
#  7   syn_flag_number  1612117 non-null  float64
#  8   rst_flag_number  1612117 non-null  float64
#  9   psh_flag_number  1612117 non-null  float64
#  10  ack_flag_number  1612117 non-null  float64
#  11  ece_flag_number  1612117 non-null  float64
#  12  cwr_flag_number  1612117 non-null  float64
#  13  ack_count        1612117 non-null  float64
#  14  syn_count        1612117 non-null  float64
#  15  fin_count        1612117 non-null  float64
#  16  rst_count        1612117 non-null  float64
#  17  HTTP             1612117 non-null  float64
#  18  HTTPS            1612117 non-null  float64
#  19  DNS              1612117 non-null  float64
#  20  Telnet           1612117 non-null  float64
#  21  SMTP             1612117 non-null  float64
#  22  SSH              1612117 non-null  float64
#  23  IRC              1612117 non-null  float64
#  24  TCP              1612117 non-null  float64
#  25  UDP              1612117 non-null  float64
#  26  DHCP             1612117 non-null  float64
#  27  ARP              1612117 non-null  float64
#  28  ICMP             1612117 non-null  float64
#  29  IGMP             1612117 non-null  float64
#  30  IPv              1612117 non-null  float64
#  31  LLC              1612117 non-null  float64
#  32  Tot sum          1612117 non-null  float64
#  33  Min              1612117 non-null  float64
#  34  Max              1612117 non-null  float64
#  35  AVG              1612117 non-null  float64
#  36  Std              1612117 non-null  float64
#  37  Tot size         1612117 non-null  float64
#  38  IAT              1612117 non-null  float64
#  39  Number           1612117 non-null  float64
#  40  Magnitue         1612117 non-null  float64
#  41  Radius           1612117 non-null  float64
#  42  Covariance       1612117 non-null  float64
#  43  Variance         1612117 non-null  float64
#  44  Weight           1612117 non-null  float64
#  45  Label            1612117 non-null  object
# dtypes: float64(45), object(1)
# memory usage: 565.8+ MB

# %%
print(df['Label'].value_counts())
# Out:
# Label
# DDoS-UDP              362070
# DDoS-ICMP             349698
# DDoS-TCP              182597
# DDoS-SYN              172397
# DoS-UDP               137553
# DoS-SYN                98595
# DoS-ICMP               98432
# DoS-TCP                82096
# DDoS-Connect_Flood     41916
# Benign                 37607
# Port_Scan              20921
# DoS-Publish_Flood       8505
# DDoS-Publish_Flood      8416
# OS_Scan                 3495
# DoS-Connect_Flood       3131
# Malformed_Data          1747
# ARP_Spoofing            1744
# VulScan                 1011
# Ping_Sweep               186
# Name: count, dtype: int64

# %%
# Define the mapping dictionary
label_mapping = {
    'Malformed_Data': 'MQTT',
    'DDoS-ICMP': 'DDoS',
    'DoS-ICMP': 'DoS',
    'DoS-TCP': 'DoS',
    'DDoS-Connect_Flood': 'MQTT',
    'DoS-Connect_Flood': 'MQTT',
    'Benign': 'Benign',
    'DoS-UDP': 'DoS',
    'Ping_Sweep': 'Recon',
    'DDoS-Publish_Flood': 'MQTT',
    'DDoS-SYN': 'DDoS',
    'DDoS-TCP': 'DDoS',
    'DoS-SYN': 'DoS',
    'DDoS-UDP': 'DDoS',
    'Port_Scan': 'Recon',
    'OS_Scan': 'Recon',
    'DoS-Publish_Flood': 'MQTT',
    'VulScan': 'Recon',
    'ARP_Spoofing': 'Spoofing'
}

# Apply the mapping to the 'Label' column
df['Label'] = df['Label'].replace(label_mapping)

# %%
print(df['Label'].value_counts())
# Out:
# Label
# DDoS        1066762
# DoS          416676
# MQTT          63715
# Benign        37607
# Recon         25613
# Spoofing       1744
# Name: count, dtype: int64

# %% [markdown]
# # Online Learning Model

# %%
# Preprocess
X = df.drop(columns=['Label'])  
y = df['Label']

X, y = shuffle(X, y, random_state=42)

# Simulate data streaming
dataset = stream.iter_pandas(X, y)

# %%
# Online Leveraging Bagging classifier
class LeveragingBaggingClassifier(base.Ensemble, base.Classifier):
    
    def __init__(self, base_estimator, n_estimators: int = 10, lambda_value: float = 6.0, seed: int = None):
        self.base_estimator = base_estimator
        self.n_estimators = n_estimators
        self.lambda_value = lambda_value
        self.seed = seed
        self._rng = random.Random(seed)
        self.learners = [base_estimator() for _ in range(n_estimators)]
    
    def learn_one(self, x: dict, y) -> "LeveragingBaggingClassifier":
        """Update each base learner using Poisson(lambda_value) sampling"""
        for learner in self.learners:
            # Draw the number of updates from a Poisson distribution with mean lambda_value
            k = np.random.poisson(self.lambda_value)
            for _ in range(k):
                learner.learn_one(x, y)
        return self
    
    def predict_proba_one(self, x: dict) -> dict:
        """Aggregate probability predictions from all base learners"""
        votes = {}
        for learner in self.learners:
            proba = learner.predict_proba_one(x)
            for label, p in proba.items():
                votes[label] = votes.get(label, 0) + p
        # Average the votes over the number of learners
        n = len(self.learners)
        if n > 0:
            for label in votes:
                votes[label] /= n
        return votes

    def predict_one(self, x: dict):
        """Return the class with the highest aggregated probability"""
        proba = self.predict_proba_one(x)
        if not proba:
            return None
        return max(proba, key=proba.get)

    def __iter__(self):
        """Allow iteration over the base learners"""
        return iter(self.learners)

# %%
# Define a factory function for the base learner
def create_hoeffding_tree():
    # Customize parameters as needed
    return tree.HoeffdingTreeClassifier(grace_period=30, delta=0.01)

# Instantiate the Leveraging Bagging classifier using the base learner factory
leveraging_bagging = LeveragingBaggingClassifier(
    base_estimator=create_hoeffding_tree,
    n_estimators=10,
    lambda_value=6.0,
    seed=42
)

# Build pipeline by adding a preprocessing step
model = compose.Pipeline(
    ('scaler', preprocessing.StandardScaler()),
    ('classifier', leveraging_bagging)
)

# %%
# Define Metrics
metric_accuracy = metrics.Accuracy()
metric_precision = metrics.WeightedPrecision()
metric_recall = metrics.WeightedRecall()
metric_f1 = metrics.WeightedF1()

# %%
# Add Drift Detector
drift_detector = drift.PageHinkley()

# Timing and visualization variables
start_time = time.time()
total_time = 0
drift_time_total = 0
metrics_time_total = 0
instance_count = 0
drift_events = []
processing_times = []
drift_time_per_instance = []
metrics_time_per_instance = []
metric_logs = {
    'accuracy': [],
    'precision': [],
    'recall': [],
    'f1_score': []
}

# %%
# Train, Evaluate, and Detect Drift
for x, y_true in dataset:
    instance_start = time.time()

    # Prediction and learning
    y_pred = model.predict_one(x)
    model.learn_one(x, y_true)

    # Time spent on metrics
    metrics_start = time.time()
    metric_accuracy.update(y_true, y_pred)
    metric_precision.update(y_true, y_pred)
    metric_recall.update(y_true, y_pred)
    metric_f1.update(y_true, y_pred)
    metrics_time_total += time.time() - metrics_start
    metrics_time_per_instance.append(time.time() - metrics_start) ###

    # Log metrics
    metric_logs['accuracy'].append(metric_accuracy.get())
    metric_logs['precision'].append(metric_precision.get())
    metric_logs['recall'].append(metric_recall.get())
    metric_logs['f1_score'].append(metric_f1.get())

    # Drift detection
    drift_start = time.time()
    drift_detector.update(int(y_pred != y_true))
    if drift_detector.drift_detected:
        detection_time = datetime.now()
        drift_events.append(instance_count)
        print(f"\nDrift detected at instance: {instance_count}")
        print(f"Detection Time: {detection_time}\n")
    drift_elapsed = time.time() - drift_start
    drift_time_total += drift_elapsed
    drift_time_per_instance.append(drift_elapsed) ###

    # Update cumulative time
    instance_time = time.time() - instance_start
    total_time += instance_time
    processing_times.append(instance_time)
    instance_count += 1

    if instance_count % 100 == 0:
        print(f"Processed {instance_count}/{len(X)} instances")

# Summary of execution times
end_time = time.time()
# Out:
# Processed 100/1612117 instances
# Processed 200/1612117 instances
# Processed 300/1612117 instances
# Processed 400/1612117 instances
# Processed 500/1612117 instances
# Processed 600/1612117 instances
# Processed 700/1612117 instances
# Processed 800/1612117 instances
# Processed 900/1612117 instances
# Processed 1000/1612117 instances
# Processed 1100/1612117 instances
# Processed 1200/1612117 instances
# Processed 1300/1612117 instances
# Processed 1400/1612117 instances
# Processed 1500/1612117 instances
# Processed 1600/1612117 instances
# Processed 1700/1612117 instances
# Processed 1800/1612117 instances
# Processed 1900/1612117 instances
# Processed 2000/1612117 instances
#
# Drift detected at instance: 2017
# Detection Time: 2025-05-01 20:33:43.800195
#
# Processed 2100/1612117 instances
# Processed 2200/1612117 instances
# Processed 2300/1612117 instances
# Processed 2400/1612117 instances
# Processed 2500/1612117 instances
# Processed 2600/1612117 instances
# Processed 2700/1612117 instances
# Processed 2800/1612117 instances
# Processed 2900/1612117 instances
# Processed 3000/1612117 instances
# Processed 3100/1612117 instances
#
# Drift detected at instance: 3198
# Detection Time: 2025-05-01 20:34:03.214649
#
# Processed 3200/1612117 instances
# Processed 3300/1612117 instances
# Processed 3400/1612117 instances
# Processed 3500/1612117 instances
# Processed 3600/1612117 instances
# Processed 3700/1612117 instances
# Processed 3800/1612117 instances
# Processed 3900/1612117 instances
# Processed 4000/1612117 instances
# Processed 4100/1612117 instances
# Processed 4200/1612117 instances
# Processed 4300/1612117 instances
# Processed 4400/1612117 instances
# Processed 4500/1612117 instances
# Processed 4600/1612117 instances
# Processed 4700/1612117 instances
# Processed 4800/1612117 instances
#
# Drift detected at instance: 4848
# Detection Time: 2025-05-01 20:34:29.537861
#
# Processed 4900/1612117 instances
# Processed 5000/1612117 instances
# Processed 5100/1612117 instances
# Processed 5200/1612117 instances
# Processed 5300/1612117 instances
# Processed 5400/1612117 instances
# Processed 5500/1612117 instances
# Processed 5600/1612117 instances
# Processed 5700/1612117 instances
# Processed 5800/1612117 instances
# Processed 5900/1612117 instances
# Processed 6000/1612117 instances
# Processed 6100/1612117 instances
# Processed 6200/1612117 instances
# Processed 6300/1612117 instances
# Processed 6400/1612117 instances
# Processed 6500/1612117 instances
# Processed 6600/1612117 instances
# Processed 6700/1612117 instances
# Processed 6800/1612117 instances
# Processed 6900/1612117 instances
# Processed 7000/1612117 instances
# Processed 7100/1612117 instances
# Processed 7200/1612117 instances
# Processed 7300/1612117 instances
# Processed 7400/1612117 instances
# Processed 7500/1612117 instances
# Processed 7600/1612117 instances
# Processed 7700/1612117 instances
# Processed 7800/1612117 instances
# Processed 7900/1612117 instances
# Processed 8000/1612117 instances
# Processed 8100/1612117 instances
# Processed 8200/1612117 instances
# Processed 8300/1612117 instances
# Processed 8400/1612117 instances
# Processed 8500/1612117 instances
# Processed 8600/1612117 instances
# Processed 8700/1612117 instances
# Processed 8800/1612117 instances
# Processed 8900/1612117 instances
# Processed 9000/1612117 instances
# Processed 9100/1612117 instances
# Processed 9200/1612117 instances
# Processed 9300/1612117 instances
# Processed 9400/1612117 instances
# Processed 9500/1612117 instances
# Processed 9600/1612117 instances
# Processed 9700/1612117 instances
# Processed 9800/1612117 instances
# Processed 9900/1612117 instances
# Processed 10000/1612117 instances
# Processed 10100/1612117 instances
# Processed 10200/1612117 instances
# Processed 10300/1612117 instances
# Processed 10400/1612117 instances
# Processed 10500/1612117 instances
# Processed 10600/1612117 instances
# Processed 10700/1612117 instances
# Processed 10800/1612117 instances
# Processed 10900/1612117 instances
# Processed 11000/1612117 instances
# Processed 11100/1612117 instances
# Processed 11200/1612117 instances
# Processed 11300/1612117 instances
# Processed 11400/1612117 instances
# Processed 11500/1612117 instances
# Processed 11600/1612117 instances
# Processed 11700/1612117 instances
# Processed 11800/1612117 instances
# Processed 11900/1612117 instances
# Processed 12000/1612117 instances
# Processed 12100/1612117 instances
# Processed 12200/1612117 instances
# Processed 12300/1612117 instances
# Processed 12400/1612117 instances
# Processed 12500/1612117 instances
# Processed 12600/1612117 instances
# Processed 12700/1612117 instances
# Processed 12800/1612117 instances
# Processed 12900/1612117 instances
# Processed 13000/1612117 instances
# Processed 13100/1612117 instances
# Processed 13200/1612117 instances
# Processed 13300/1612117 instances
# Processed 13400/1612117 instances
# Processed 13500/1612117 instances
# Processed 13600/1612117 instances
# Processed 13700/1612117 instances
# Processed 13800/1612117 instances
# Processed 13900/1612117 instances
# Processed 14000/1612117 instances
# Processed 14100/1612117 instances
# Processed 14200/1612117 instances
# Processed 14300/1612117 instances
# Processed 14400/1612117 instances
# Processed 14500/1612117 instances
# Processed 14600/1612117 instances
# Processed 14700/1612117 instances
# Processed 14800/1612117 instances
# Processed 14900/1612117 instances
# Processed 15000/1612117 instances
# Processed 15100/1612117 instances
# Processed 15200/1612117 instances
# Processed 15300/1612117 instances
# Processed 15400/1612117 instances
# Processed 15500/1612117 instances
# Processed 15600/1612117 instances
# Processed 15700/1612117 instances
# Processed 15800/1612117 instances
# Processed 15900/1612117 instances
# Processed 16000/1612117 instances
# Processed 16100/1612117 instances
# Processed 16200/1612117 instances
# Processed 16300/1612117 instances
# Processed 16400/1612117 instances
# Processed 16500/1612117 instances
# Processed 16600/1612117 instances
# Processed 16700/1612117 instances
# Processed 16800/1612117 instances
# Processed 16900/1612117 instances
# Processed 17000/1612117 instances
# Processed 17100/1612117 instances
# Processed 17200/1612117 instances
# Processed 17300/1612117 instances
# Processed 17400/1612117 instances
# Processed 17500/1612117 instances
# Processed 17600/1612117 instances
# Processed 17700/1612117 instances
# Processed 17800/1612117 instances
# Processed 17900/1612117 instances
# Processed 18000/1612117 instances
# Processed 18100/1612117 instances
# Processed 18200/1612117 instances
# Processed 18300/1612117 instances
# Processed 18400/1612117 instances
# Processed 18500/1612117 instances
# Processed 18600/1612117 instances
# Processed 18700/1612117 instances
# Processed 18800/1612117 instances
# Processed 18900/1612117 instances
# Processed 19000/1612117 instances
# Processed 19100/1612117 instances
# Processed 19200/1612117 instances
# Processed 19300/1612117 instances
# Processed 19400/1612117 instances
# Processed 19500/1612117 instances
# Processed 19600/1612117 instances
# Processed 19700/1612117 instances
# Processed 19800/1612117 instances
# Processed 19900/1612117 instances
# Processed 20000/1612117 instances
# Processed 20100/1612117 instances
# Processed 20200/1612117 instances
# Processed 20300/1612117 instances
# Processed 20400/1612117 instances
# Processed 20500/1612117 instances
# Processed 20600/1612117 instances
# Processed 20700/1612117 instances
# Processed 20800/1612117 instances
# Processed 20900/1612117 instances
# Processed 21000/1612117 instances
# Processed 21100/1612117 instances
# Processed 21200/1612117 instances
# Processed 21300/1612117 instances
# Processed 21400/1612117 instances
#
# Drift detected at instance: 21462
# Detection Time: 2025-05-01 20:38:12.112993
#
# Processed 21500/1612117 instances
# Processed 21600/1612117 instances
# Processed 21700/1612117 instances
# Processed 21800/1612117 instances
# Processed 21900/1612117 instances
# Processed 22000/1612117 instances
# Processed 22100/1612117 instances
# Processed 22200/1612117 instances
# Processed 22300/1612117 instances
# Processed 22400/1612117 instances
# Processed 22500/1612117 instances
# Processed 22600/1612117 instances
# Processed 22700/1612117 instances
# Processed 22800/1612117 instances
# Processed 22900/1612117 instances
# Processed 23000/1612117 instances
# Processed 23100/1612117 instances
# Processed 23200/1612117 instances
# Processed 23300/1612117 instances
# Processed 23400/1612117 instances
# Processed 23500/1612117 instances
# Processed 23600/1612117 instances
# Processed 23700/1612117 instances
# Processed 23800/1612117 instances
# Processed 23900/1612117 instances
# Processed 24000/1612117 instances
# Processed 24100/1612117 instances
# Processed 24200/1612117 instances
# Processed 24300/1612117 instances
# Processed 24400/1612117 instances
# Processed 24500/1612117 instances
# Processed 24600/1612117 instances
# Processed 24700/1612117 instances
# Processed 24800/1612117 instances
# Processed 24900/1612117 instances
# Processed 25000/1612117 instances
# Processed 25100/1612117 instances
# Processed 25200/1612117 instances
# Processed 25300/1612117 instances
# Processed 25400/1612117 instances
# Processed 25500/1612117 instances
# Processed 25600/1612117 instances
# Processed 25700/1612117 instances
# Processed 25800/1612117 instances
# Processed 25900/1612117 instances
# Processed 26000/1612117 instances
# Processed 26100/1612117 instances
# Processed 26200/1612117 instances
# Processed 26300/1612117 instances
# Processed 26400/1612117 instances
# Processed 26500/1612117 instances
# Processed 26600/1612117 instances
# Processed 26700/1612117 instances
# Processed 26800/1612117 instances
# Processed 26900/1612117 instances
# Processed 27000/1612117 instances
# Processed 27100/1612117 instances
# Processed 27200/1612117 instances
# Processed 27300/1612117 instances
# Processed 27400/1612117 instances
# Processed 27500/1612117 instances
# Processed 27600/1612117 instances
# Processed 27700/1612117 instances
# Processed 27800/1612117 instances
# Processed 27900/1612117 instances
# Processed 28000/1612117 instances
# Processed 28100/1612117 instances
# Processed 28200/1612117 instances
# Processed 28300/1612117 instances
# Processed 28400/1612117 instances
# Processed 28500/1612117 instances
# Processed 28600/1612117 instances
# Processed 28700/1612117 instances
# Processed 28800/1612117 instances
# Processed 28900/1612117 instances
# Processed 29000/1612117 instances
# Processed 29100/1612117 instances
# Processed 29200/1612117 instances
# Processed 29300/1612117 instances
# Processed 29400/1612117 instances
# Processed 29500/1612117 instances
# Processed 29600/1612117 instances
# Processed 29700/1612117 instances
# Processed 29800/1612117 instances
# Processed 29900/1612117 instances
# Processed 30000/1612117 instances
# Processed 30100/1612117 instances
# Processed 30200/1612117 instances
# Processed 30300/1612117 instances
# Processed 30400/1612117 instances
# Processed 30500/1612117 instances
# Processed 30600/1612117 instances
# Processed 30700/1612117 instances
# Processed 30800/1612117 instances
# Processed 30900/1612117 instances
# Processed 31000/1612117 instances
# Processed 31100/1612117 instances
# Processed 31200/1612117 instances
# Processed 31300/1612117 instances
# Processed 31400/1612117 instances
# Processed 31500/1612117 instances
# Processed 31600/1612117 instances
# Processed 31700/1612117 instances
# Processed 31800/1612117 instances
# Processed 31900/1612117 instances
# Processed 32000/1612117 instances
# Processed 32100/1612117 instances
# Processed 32200/1612117 instances
# Processed 32300/1612117 instances
# Processed 32400/1612117 instances
# Processed 32500/1612117 instances
# Processed 32600/1612117 instances
# Processed 32700/1612117 instances
# Processed 32800/1612117 instances
# Processed 32900/1612117 instances
# Processed 33000/1612117 instances
# Processed 33100/1612117 instances
# Processed 33200/1612117 instances
# Processed 33300/1612117 instances
# Processed 33400/1612117 instances
# Processed 33500/1612117 instances
# Processed 33600/1612117 instances
# Processed 33700/1612117 instances
# Processed 33800/1612117 instances
# Processed 33900/1612117 instances
# Processed 34000/1612117 instances
# Processed 34100/1612117 instances
# Processed 34200/1612117 instances
# Processed 34300/1612117 instances
# Processed 34400/1612117 instances
# Processed 34500/1612117 instances
# Processed 34600/1612117 instances
# Processed 34700/1612117 instances
# Processed 34800/1612117 instances
# Processed 34900/1612117 instances
# Processed 35000/1612117 instances
# Processed 35100/1612117 instances
# Processed 35200/1612117 instances
# Processed 35300/1612117 instances
# Processed 35400/1612117 instances
# Processed 35500/1612117 instances
# Processed 35600/1612117 instances
# Processed 35700/1612117 instances
# Processed 35800/1612117 instances
# Processed 35900/1612117 instances
# Processed 36000/1612117 instances
# Processed 36100/1612117 instances
# Processed 36200/1612117 instances
# Processed 36300/1612117 instances
# Processed 36400/1612117 instances
# Processed 36500/1612117 instances
# Processed 36600/1612117 instances
# Processed 36700/1612117 instances
# Processed 36800/1612117 instances
# Processed 36900/1612117 instances
# Processed 37000/1612117 instances
# Processed 37100/1612117 instances
# Processed 37200/1612117 instances
# Processed 37300/1612117 instances
# Processed 37400/1612117 instances
# Processed 37500/1612117 instances
# Processed 37600/1612117 instances
# Processed 37700/1612117 instances
# Processed 37800/1612117 instances
# Processed 37900/1612117 instances
# Processed 38000/1612117 instances
# Processed 38100/1612117 instances
# Processed 38200/1612117 instances
# Processed 38300/1612117 instances
# Processed 38400/1612117 instances
# Processed 38500/1612117 instances
# Processed 38600/1612117 instances
# Processed 38700/1612117 instances
# Processed 38800/1612117 instances
# Processed 38900/1612117 instances
# Processed 39000/1612117 instances
# Processed 39100/1612117 instances
# Processed 39200/1612117 instances
# Processed 39300/1612117 instances
# Processed 39400/1612117 instances
# Processed 39500/1612117 instances
# Processed 39600/1612117 instances
# Processed 39700/1612117 instances
# Processed 39800/1612117 instances
# Processed 39900/1612117 instances
# Processed 40000/1612117 instances
# Processed 40100/1612117 instances
# Processed 40200/1612117 instances
# Processed 40300/1612117 instances
# Processed 40400/1612117 instances
# Processed 40500/1612117 instances
# Processed 40600/1612117 instances
# Processed 40700/1612117 instances
# Processed 40800/1612117 instances
# Processed 40900/1612117 instances
# Processed 41000/1612117 instances
# Processed 41100/1612117 instances
# Processed 41200/1612117 instances
# Processed 41300/1612117 instances
# Processed 41400/1612117 instances
# Processed 41500/1612117 instances
# Processed 41600/1612117 instances
# Processed 41700/1612117 instances
# Processed 41800/1612117 instances
# Processed 41900/1612117 instances
# Processed 42000/1612117 instances
# Processed 42100/1612117 instances
# Processed 42200/1612117 instances
# Processed 42300/1612117 instances
# Processed 42400/1612117 instances
# Processed 42500/1612117 instances
# Processed 42600/1612117 instances
# Processed 42700/1612117 instances
# Processed 42800/1612117 instances
# Processed 42900/1612117 instances
# Processed 43000/1612117 instances
# Processed 43100/1612117 instances
# Processed 43200/1612117 instances
# Processed 43300/1612117 instances
# Processed 43400/1612117 instances
# Processed 43500/1612117 instances
# Processed 43600/1612117 instances
# Processed 43700/1612117 instances
# Processed 43800/1612117 instances
# Processed 43900/1612117 instances
# Processed 44000/1612117 instances
# Processed 44100/1612117 instances
# Processed 44200/1612117 instances
# Processed 44300/1612117 instances
# Processed 44400/1612117 instances
# Processed 44500/1612117 instances
# Processed 44600/1612117 instances
# Processed 44700/1612117 instances
# Processed 44800/1612117 instances
# Processed 44900/1612117 instances
# Processed 45000/1612117 instances
# Processed 45100/1612117 instances
# Processed 45200/1612117 instances
# Processed 45300/1612117 instances
# Processed 45400/1612117 instances
# Processed 45500/1612117 instances
# Processed 45600/1612117 instances
# Processed 45700/1612117 instances
# Processed 45800/1612117 instances
# Processed 45900/1612117 instances
# Processed 46000/1612117 instances
# Processed 46100/1612117 instances
# Processed 46200/1612117 instances
# Processed 46300/1612117 instances
# Processed 46400/1612117 instances
# Processed 46500/1612117 instances
# Processed 46600/1612117 instances
# Processed 46700/1612117 instances
# Processed 46800/1612117 instances
# Processed 46900/1612117 instances
# Processed 47000/1612117 instances
# Processed 47100/1612117 instances
# Processed 47200/1612117 instances
# Processed 47300/1612117 instances
# Processed 47400/1612117 instances
# Processed 47500/1612117 instances
# Processed 47600/1612117 instances
# Processed 47700/1612117 instances
# Processed 47800/1612117 instances
# Processed 47900/1612117 instances
# Processed 48000/1612117 instances
# Processed 48100/1612117 instances
# Processed 48200/1612117 instances
# Processed 48300/1612117 instances
# Processed 48400/1612117 instances
# Processed 48500/1612117 instances
# Processed 48600/1612117 instances
# Processed 48700/1612117 instances
# Processed 48800/1612117 instances
# Processed 48900/1612117 instances
# Processed 49000/1612117 instances
# Processed 49100/1612117 instances
# Processed 49200/1612117 instances
# Processed 49300/1612117 instances
# Processed 49400/1612117 instances
# Processed 49500/1612117 instances
# Processed 49600/1612117 instances
# Processed 49700/1612117 instances
# Processed 49800/1612117 instances
# Processed 49900/1612117 instances
# Processed 50000/1612117 instances
# Processed 50100/1612117 instances
# Processed 50200/1612117 instances
# Processed 50300/1612117 instances
# Processed 50400/1612117 instances
# Processed 50500/1612117 instances
# Processed 50600/1612117 instances
# Processed 50700/1612117 instances
# Processed 50800/1612117 instances
# Processed 50900/1612117 instances
# Processed 51000/1612117 instances
# Processed 51100/1612117 instances
# Processed 51200/1612117 instances
# Processed 51300/1612117 instances
# Processed 51400/1612117 instances
# Processed 51500/1612117 instances
# Processed 51600/1612117 instances
# Processed 51700/1612117 instances
# Processed 51800/1612117 instances
# Processed 51900/1612117 instances
# Processed 52000/1612117 instances
# Processed 52100/1612117 instances
# Processed 52200/1612117 instances
# Processed 52300/1612117 instances
# Processed 52400/1612117 instances
# Processed 52500/1612117 instances
# Processed 52600/1612117 instances
# Processed 52700/1612117 instances
# Processed 52800/1612117 instances
# Processed 52900/1612117 instances
# Processed 53000/1612117 instances
# Processed 53100/1612117 instances
# Processed 53200/1612117 instances
# Processed 53300/1612117 instances
# Processed 53400/1612117 instances
# Processed 53500/1612117 instances
# Processed 53600/1612117 instances
# Processed 53700/1612117 instances
# Processed 53800/1612117 instances
# Processed 53900/1612117 instances
# Processed 54000/1612117 instances
# Processed 54100/1612117 instances
# Processed 54200/1612117 instances
# Processed 54300/1612117 instances
# Processed 54400/1612117 instances
# Processed 54500/1612117 instances
# Processed 54600/1612117 instances
# Processed 54700/1612117 instances
# Processed 54800/1612117 instances
# Processed 54900/1612117 instances
# Processed 55000/1612117 instances
# Processed 55100/1612117 instances
# Processed 55200/1612117 instances
# Processed 55300/1612117 instances
# Processed 55400/1612117 instances
# Processed 55500/1612117 instances
# Processed 55600/1612117 instances
# Processed 55700/1612117 instances
# Processed 55800/1612117 instances
# Processed 55900/1612117 instances
# Processed 56000/1612117 instances
# Processed 56100/1612117 instances
# Processed 56200/1612117 instances
# Processed 56300/1612117 instances
# Processed 56400/1612117 instances
# Processed 56500/1612117 instances
# Processed 56600/1612117 instances
# Processed 56700/1612117 instances
# Processed 56800/1612117 instances
# Processed 56900/1612117 instances
# Processed 57000/1612117 instances
# Processed 57100/1612117 instances
# Processed 57200/1612117 instances
# Processed 57300/1612117 instances
# Processed 57400/1612117 instances
# Processed 57500/1612117 instances
# Processed 57600/1612117 instances
# Processed 57700/1612117 instances
# Processed 57800/1612117 instances
# Processed 57900/1612117 instances
# Processed 58000/1612117 instances
# Processed 58100/1612117 instances
# Processed 58200/1612117 instances
# Processed 58300/1612117 instances
# Processed 58400/1612117 instances
# Processed 58500/1612117 instances
# Processed 58600/1612117 instances
# Processed 58700/1612117 instances
# Processed 58800/1612117 instances
# Processed 58900/1612117 instances
# Processed 59000/1612117 instances
# Processed 59100/1612117 instances
# Processed 59200/1612117 instances
# Processed 59300/1612117 instances
# Processed 59400/1612117 instances
# Processed 59500/1612117 instances
# Processed 59600/1612117 instances
# Processed 59700/1612117 instances
# Processed 59800/1612117 instances
# Processed 59900/1612117 instances
# Processed 60000/1612117 instances
# Processed 60100/1612117 instances
# Processed 60200/1612117 instances
# Processed 60300/1612117 instances
# Processed 60400/1612117 instances
# Processed 60500/1612117 instances
# Processed 60600/1612117 instances
# Processed 60700/1612117 instances
# Processed 60800/1612117 instances
# Processed 60900/1612117 instances
# Processed 61000/1612117 instances
# Processed 61100/1612117 instances
# Processed 61200/1612117 instances
# Processed 61300/1612117 instances
# Processed 61400/1612117 instances
# Processed 61500/1612117 instances
# Processed 61600/1612117 instances
# Processed 61700/1612117 instances
# Processed 61800/1612117 instances
# Processed 61900/1612117 instances
# Processed 62000/1612117 instances
# Processed 62100/1612117 instances
# Processed 62200/1612117 instances
# Processed 62300/1612117 instances
# Processed 62400/1612117 instances
# Processed 62500/1612117 instances
# Processed 62600/1612117 instances
# Processed 62700/1612117 instances
# Processed 62800/1612117 instances
# Processed 62900/1612117 instances
# Processed 63000/1612117 instances
# Processed 63100/1612117 instances
# Processed 63200/1612117 instances
# Processed 63300/1612117 instances
# Processed 63400/1612117 instances
# Processed 63500/1612117 instances
# Processed 63600/1612117 instances
# Processed 63700/1612117 instances
# Processed 63800/1612117 instances
# Processed 63900/1612117 instances
# Processed 64000/1612117 instances
# Processed 64100/1612117 instances
# Processed 64200/1612117 instances
# Processed 64300/1612117 instances
# Processed 64400/1612117 instances
# Processed 64500/1612117 instances
# Processed 64600/1612117 instances
# Processed 64700/1612117 instances
# Processed 64800/1612117 instances
# Processed 64900/1612117 instances
# Processed 65000/1612117 instances
# Processed 65100/1612117 instances
# Processed 65200/1612117 instances
# Processed 65300/1612117 instances
# Processed 65400/1612117 instances
# Processed 65500/1612117 instances
# Processed 65600/1612117 instances
# Processed 65700/1612117 instances
# Processed 65800/1612117 instances
# Processed 65900/1612117 instances
# Processed 66000/1612117 instances
# Processed 66100/1612117 instances
# Processed 66200/1612117 instances
# Processed 66300/1612117 instances
# Processed 66400/1612117 instances
# Processed 66500/1612117 instances
# Processed 66600/1612117 instances
# Processed 66700/1612117 instances
# Processed 66800/1612117 instances
# Processed 66900/1612117 instances
# Processed 67000/1612117 instances
# Processed 67100/1612117 instances
# Processed 67200/1612117 instances
# Processed 67300/1612117 instances
# Processed 67400/1612117 instances
# Processed 67500/1612117 instances
# Processed 67600/1612117 instances
# Processed 67700/1612117 instances
# Processed 67800/1612117 instances
# Processed 67900/1612117 instances
# Processed 68000/1612117 instances
# Processed 68100/1612117 instances
# Processed 68200/1612117 instances
# Processed 68300/1612117 instances
# Processed 68400/1612117 instances
# Processed 68500/1612117 instances
# Processed 68600/1612117 instances
# Processed 68700/1612117 instances
# Processed 68800/1612117 instances
# Processed 68900/1612117 instances
# Processed 69000/1612117 instances
# Processed 69100/1612117 instances
# Processed 69200/1612117 instances
# Processed 69300/1612117 instances
# Processed 69400/1612117 instances
# Processed 69500/1612117 instances
# Processed 69600/1612117 instances
# Processed 69700/1612117 instances
# Processed 69800/1612117 instances
# Processed 69900/1612117 instances
# Processed 70000/1612117 instances
# Processed 70100/1612117 instances
# Processed 70200/1612117 instances
# Processed 70300/1612117 instances
# Processed 70400/1612117 instances
# Processed 70500/1612117 instances
# Processed 70600/1612117 instances
# Processed 70700/1612117 instances
# Processed 70800/1612117 instances
# Processed 70900/1612117 instances
# Processed 71000/1612117 instances
# Processed 71100/1612117 instances
# Processed 71200/1612117 instances
# Processed 71300/1612117 instances
# Processed 71400/1612117 instances
# Processed 71500/1612117 instances
# Processed 71600/1612117 instances
# Processed 71700/1612117 instances
# Processed 71800/1612117 instances
# Processed 71900/1612117 instances
# Processed 72000/1612117 instances
# Processed 72100/1612117 instances
# Processed 72200/1612117 instances
# Processed 72300/1612117 instances
# Processed 72400/1612117 instances
# Processed 72500/1612117 instances
# Processed 72600/1612117 instances
# Processed 72700/1612117 instances
# Processed 72800/1612117 instances
# Processed 72900/1612117 instances
# Processed 73000/1612117 instances
# Processed 73100/1612117 instances
# Processed 73200/1612117 instances
# Processed 73300/1612117 instances
# Processed 73400/1612117 instances
# Processed 73500/1612117 instances
# Processed 73600/1612117 instances
# Processed 73700/1612117 instances
# Processed 73800/1612117 instances
# Processed 73900/1612117 instances
# Processed 74000/1612117 instances
# Processed 74100/1612117 instances
# Processed 74200/1612117 instances
# Processed 74300/1612117 instances
# Processed 74400/1612117 instances
# Processed 74500/1612117 instances
# Processed 74600/1612117 instances
# Processed 74700/1612117 instances
# Processed 74800/1612117 instances
# Processed 74900/1612117 instances
# Processed 75000/1612117 instances
# Processed 75100/1612117 instances
# Processed 75200/1612117 instances
# Processed 75300/1612117 instances
# Processed 75400/1612117 instances
# Processed 75500/1612117 instances
# Processed 75600/1612117 instances
# Processed 75700/1612117 instances
# Processed 75800/1612117 instances
# Processed 75900/1612117 instances
# Processed 76000/1612117 instances
# Processed 76100/1612117 instances
# Processed 76200/1612117 instances
# Processed 76300/1612117 instances
# Processed 76400/1612117 instances
# Processed 76500/1612117 instances
# Processed 76600/1612117 instances
# Processed 76700/1612117 instances
# Processed 76800/1612117 instances
# Processed 76900/1612117 instances
# Processed 77000/1612117 instances
# Processed 77100/1612117 instances
# Processed 77200/1612117 instances
# Processed 77300/1612117 instances
# Processed 77400/1612117 instances
# Processed 77500/1612117 instances
# Processed 77600/1612117 instances
# Processed 77700/1612117 instances
# Processed 77800/1612117 instances
# Processed 77900/1612117 instances
# Processed 78000/1612117 instances
# Processed 78100/1612117 instances
# Processed 78200/1612117 instances
# Processed 78300/1612117 instances
# Processed 78400/1612117 instances
# Processed 78500/1612117 instances
# Processed 78600/1612117 instances
# Processed 78700/1612117 instances
# Processed 78800/1612117 instances
# Processed 78900/1612117 instances
# Processed 79000/1612117 instances
# Processed 79100/1612117 instances
# Processed 79200/1612117 instances
# Processed 79300/1612117 instances
# Processed 79400/1612117 instances
# Processed 79500/1612117 instances
# Processed 79600/1612117 instances
# Processed 79700/1612117 instances
# Processed 79800/1612117 instances
# Processed 79900/1612117 instances
# Processed 80000/1612117 instances
# Processed 80100/1612117 instances
# Processed 80200/1612117 instances
# Processed 80300/1612117 instances
# Processed 80400/1612117 instances
# Processed 80500/1612117 instances
# Processed 80600/1612117 instances
# Processed 80700/1612117 instances
# Processed 80800/1612117 instances
# Processed 80900/1612117 instances
# Processed 81000/1612117 instances
# Processed 81100/1612117 instances
# Processed 81200/1612117 instances
# Processed 81300/1612117 instances
# Processed 81400/1612117 instances
# Processed 81500/1612117 instances
# Processed 81600/1612117 instances
# Processed 81700/1612117 instances
# Processed 81800/1612117 instances
# Processed 81900/1612117 instances
# Processed 82000/1612117 instances
# Processed 82100/1612117 instances
# Processed 82200/1612117 instances
# Processed 82300/1612117 instances
# Processed 82400/1612117 instances
# Processed 82500/1612117 instances
# Processed 82600/1612117 instances
# Processed 82700/1612117 instances
# Processed 82800/1612117 instances
# Processed 82900/1612117 instances
# Processed 83000/1612117 instances
# Processed 83100/1612117 instances
# Processed 83200/1612117 instances
# Processed 83300/1612117 instances
# Processed 83400/1612117 instances
# Processed 83500/1612117 instances
# Processed 83600/1612117 instances
# Processed 83700/1612117 instances
# Processed 83800/1612117 instances
# Processed 83900/1612117 instances
# Processed 84000/1612117 instances
# Processed 84100/1612117 instances
# Processed 84200/1612117 instances
# Processed 84300/1612117 instances
# Processed 84400/1612117 instances
# Processed 84500/1612117 instances
# Processed 84600/1612117 instances
# Processed 84700/1612117 instances
# Processed 84800/1612117 instances
# Processed 84900/1612117 instances
# Processed 85000/1612117 instances
# Processed 85100/1612117 instances
# Processed 85200/1612117 instances
# Processed 85300/1612117 instances
# Processed 85400/1612117 instances
# Processed 85500/1612117 instances
# Processed 85600/1612117 instances
# Processed 85700/1612117 instances
# Processed 85800/1612117 instances
# Processed 85900/1612117 instances
# Processed 86000/1612117 instances
# Processed 86100/1612117 instances
# Processed 86200/1612117 instances
# Processed 86300/1612117 instances
# Processed 86400/1612117 instances
# Processed 86500/1612117 instances
# Processed 86600/1612117 instances
# Processed 86700/1612117 instances
# Processed 86800/1612117 instances
# Processed 86900/1612117 instances
# Processed 87000/1612117 instances
# Processed 87100/1612117 instances
# Processed 87200/1612117 instances
# Processed 87300/1612117 instances
# Processed 87400/1612117 instances
# Processed 87500/1612117 instances
# Processed 87600/1612117 instances
# Processed 87700/1612117 instances
# Processed 87800/1612117 instances
# Processed 87900/1612117 instances
# Processed 88000/1612117 instances
# Processed 88100/1612117 instances
# Processed 88200/1612117 instances
# Processed 88300/1612117 instances
# Processed 88400/1612117 instances
# Processed 88500/1612117 instances
# Processed 88600/1612117 instances
# Processed 88700/1612117 instances
# Processed 88800/1612117 instances
# Processed 88900/1612117 instances
# Processed 89000/1612117 instances
# Processed 89100/1612117 instances
# Processed 89200/1612117 instances
# Processed 89300/1612117 instances
# Processed 89400/1612117 instances
# Processed 89500/1612117 instances
# Processed 89600/1612117 instances
# Processed 89700/1612117 instances
# Processed 89800/1612117 instances
# Processed 89900/1612117 instances
# Processed 90000/1612117 instances
# Processed 90100/1612117 instances
# Processed 90200/1612117 instances
# Processed 90300/1612117 instances
# Processed 90400/1612117 instances
# Processed 90500/1612117 instances
# Processed 90600/1612117 instances
# Processed 90700/1612117 instances
# Processed 90800/1612117 instances
# Processed 90900/1612117 instances
# Processed 91000/1612117 instances
# Processed 91100/1612117 instances
# Processed 91200/1612117 instances
# Processed 91300/1612117 instances
# Processed 91400/1612117 instances
# Processed 91500/1612117 instances
# Processed 91600/1612117 instances
# Processed 91700/1612117 instances
# Processed 91800/1612117 instances
# Processed 91900/1612117 instances
# Processed 92000/1612117 instances
# Processed 92100/1612117 instances
# Processed 92200/1612117 instances
# Processed 92300/1612117 instances
# Processed 92400/1612117 instances
# Processed 92500/1612117 instances
# Processed 92600/1612117 instances
# Processed 92700/1612117 instances
# Processed 92800/1612117 instances
# Processed 92900/1612117 instances
# Processed 93000/1612117 instances
# Processed 93100/1612117 instances
# Processed 93200/1612117 instances
# Processed 93300/1612117 instances
# Processed 93400/1612117 instances
# Processed 93500/1612117 instances
# Processed 93600/1612117 instances
# Processed 93700/1612117 instances
# Processed 93800/1612117 instances
# Processed 93900/1612117 instances
# Processed 94000/1612117 instances
# Processed 94100/1612117 instances
# Processed 94200/1612117 instances
# Processed 94300/1612117 instances
# Processed 94400/1612117 instances
# Processed 94500/1612117 instances
# Processed 94600/1612117 instances
# Processed 94700/1612117 instances
# Processed 94800/1612117 instances
# Processed 94900/1612117 instances
# Processed 95000/1612117 instances
# Processed 95100/1612117 instances
# Processed 95200/1612117 instances
# Processed 95300/1612117 instances
# Processed 95400/1612117 instances
# Processed 95500/1612117 instances
# Processed 95600/1612117 instances
# Processed 95700/1612117 instances
# Processed 95800/1612117 instances
# Processed 95900/1612117 instances
# Processed 96000/1612117 instances
# Processed 96100/1612117 instances
# Processed 96200/1612117 instances
# Processed 96300/1612117 instances
# Processed 96400/1612117 instances
# Processed 96500/1612117 instances
# Processed 96600/1612117 instances
# Processed 96700/1612117 instances
# Processed 96800/1612117 instances
# Processed 96900/1612117 instances
# Processed 97000/1612117 instances
# Processed 97100/1612117 instances
# Processed 97200/1612117 instances
# Processed 97300/1612117 instances
# Processed 97400/1612117 instances
# Processed 97500/1612117 instances
# Processed 97600/1612117 instances
# Processed 97700/1612117 instances
# Processed 97800/1612117 instances
# Processed 97900/1612117 instances
# Processed 98000/1612117 instances
# Processed 98100/1612117 instances
# Processed 98200/1612117 instances
# Processed 98300/1612117 instances
# Processed 98400/1612117 instances
# Processed 98500/1612117 instances
# Processed 98600/1612117 instances
# Processed 98700/1612117 instances
# Processed 98800/1612117 instances
# Processed 98900/1612117 instances
# Processed 99000/1612117 instances
# Processed 99100/1612117 instances
# Processed 99200/1612117 instances
# Processed 99300/1612117 instances
# Processed 99400/1612117 instances
# Processed 99500/1612117 instances
# Processed 99600/1612117 instances
# Processed 99700/1612117 instances
# Processed 99800/1612117 instances
# Processed 99900/1612117 instances
# Processed 100000/1612117 instances
# Processed 100100/1612117 instances
# Processed 100200/1612117 instances
# Processed 100300/1612117 instances
# Processed 100400/1612117 instances
# Processed 100500/1612117 instances
# Processed 100600/1612117 instances
# Processed 100700/1612117 instances
# Processed 100800/1612117 instances
# Processed 100900/1612117 instances
# Processed 101000/1612117 instances
# Processed 101100/1612117 instances
# Processed 101200/1612117 instances
# Processed 101300/1612117 instances
# Processed 101400/1612117 instances
# Processed 101500/1612117 instances
# Processed 101600/1612117 instances
# Processed 101700/1612117 instances
# Processed 101800/1612117 instances
# Processed 101900/1612117 instances
# Processed 102000/1612117 instances
# Processed 102100/1612117 instances
# Processed 102200/1612117 instances
# Processed 102300/1612117 instances
# Processed 102400/1612117 instances
# Processed 102500/1612117 instances
# Processed 102600/1612117 instances
# Processed 102700/1612117 instances
# Processed 102800/1612117 instances
# Processed 102900/1612117 instances
# Processed 103000/1612117 instances
# Processed 103100/1612117 instances
# Processed 103200/1612117 instances
# Processed 103300/1612117 instances
# Processed 103400/1612117 instances
# Processed 103500/1612117 instances
# Processed 103600/1612117 instances
# Processed 103700/1612117 instances
# Processed 103800/1612117 instances
# Processed 103900/1612117 instances
# Processed 104000/1612117 instances
# Processed 104100/1612117 instances
# Processed 104200/1612117 instances
# Processed 104300/1612117 instances
# Processed 104400/1612117 instances
# Processed 104500/1612117 instances
# Processed 104600/1612117 instances
# Processed 104700/1612117 instances
# Processed 104800/1612117 instances
# Processed 104900/1612117 instances
# Processed 105000/1612117 instances
# Processed 105100/1612117 instances
# Processed 105200/1612117 instances
# Processed 105300/1612117 instances
# Processed 105400/1612117 instances
# Processed 105500/1612117 instances
# Processed 105600/1612117 instances
# Processed 105700/1612117 instances
# Processed 105800/1612117 instances
# Processed 105900/1612117 instances
# Processed 106000/1612117 instances
# Processed 106100/1612117 instances
# Processed 106200/1612117 instances
# Processed 106300/1612117 instances
# Processed 106400/1612117 instances
# Processed 106500/1612117 instances
# Processed 106600/1612117 instances
# Processed 106700/1612117 instances
# Processed 106800/1612117 instances
# Processed 106900/1612117 instances
# Processed 107000/1612117 instances
# Processed 107100/1612117 instances
# Processed 107200/1612117 instances
# Processed 107300/1612117 instances
# Processed 107400/1612117 instances
# Processed 107500/1612117 instances
# Processed 107600/1612117 instances
# Processed 107700/1612117 instances
# Processed 107800/1612117 instances
# Processed 107900/1612117 instances
# Processed 108000/1612117 instances
# Processed 108100/1612117 instances
# Processed 108200/1612117 instances
# Processed 108300/1612117 instances
# Processed 108400/1612117 instances
# Processed 108500/1612117 instances
# Processed 108600/1612117 instances
# Processed 108700/1612117 instances
# Processed 108800/1612117 instances
# Processed 108900/1612117 instances
# Processed 109000/1612117 instances
# Processed 109100/1612117 instances
# Processed 109200/1612117 instances
# Processed 109300/1612117 instances
# Processed 109400/1612117 instances
# Processed 109500/1612117 instances
# Processed 109600/1612117 instances
# Processed 109700/1612117 instances
# Processed 109800/1612117 instances
# Processed 109900/1612117 instances
# Processed 110000/1612117 instances
# Processed 110100/1612117 instances
# Processed 110200/1612117 instances
# Processed 110300/1612117 instances
# Processed 110400/1612117 instances
# Processed 110500/1612117 instances
# Processed 110600/1612117 instances
# Processed 110700/1612117 instances
# Processed 110800/1612117 instances
# Processed 110900/1612117 instances
# Processed 111000/1612117 instances
# Processed 111100/1612117 instances
# Processed 111200/1612117 instances
# Processed 111300/1612117 instances
# Processed 111400/1612117 instances
# Processed 111500/1612117 instances
# Processed 111600/1612117 instances
# Processed 111700/1612117 instances
# Processed 111800/1612117 instances
# Processed 111900/1612117 instances
# Processed 112000/1612117 instances
# Processed 112100/1612117 instances
# Processed 112200/1612117 instances
# Processed 112300/1612117 instances
# Processed 112400/1612117 instances
# Processed 112500/1612117 instances
# Processed 112600/1612117 instances
# Processed 112700/1612117 instances
# Processed 112800/1612117 instances
# Processed 112900/1612117 instances
# Processed 113000/1612117 instances
# Processed 113100/1612117 instances
# Processed 113200/1612117 instances
# Processed 113300/1612117 instances
# Processed 113400/1612117 instances
# Processed 113500/1612117 instances
# Processed 113600/1612117 instances
# Processed 113700/1612117 instances
# Processed 113800/1612117 instances
# Processed 113900/1612117 instances
# Processed 114000/1612117 instances
# Processed 114100/1612117 instances
# Processed 114200/1612117 instances
# Processed 114300/1612117 instances
# Processed 114400/1612117 instances
# Processed 114500/1612117 instances
# Processed 114600/1612117 instances
# Processed 114700/1612117 instances
# Processed 114800/1612117 instances
# Processed 114900/1612117 instances
# Processed 115000/1612117 instances
# Processed 115100/1612117 instances
# Processed 115200/1612117 instances
# Processed 115300/1612117 instances
# Processed 115400/1612117 instances
# Processed 115500/1612117 instances
# Processed 115600/1612117 instances
# Processed 115700/1612117 instances
# Processed 115800/1612117 instances
# Processed 115900/1612117 instances
# Processed 116000/1612117 instances
# Processed 116100/1612117 instances
# Processed 116200/1612117 instances
# Processed 116300/1612117 instances
# Processed 116400/1612117 instances
# Processed 116500/1612117 instances
# Processed 116600/1612117 instances
# Processed 116700/1612117 instances
# Processed 116800/1612117 instances
# Processed 116900/1612117 instances
# Processed 117000/1612117 instances
# Processed 117100/1612117 instances
# Processed 117200/1612117 instances
# Processed 117300/1612117 instances
# Processed 117400/1612117 instances
# Processed 117500/1612117 instances
# Processed 117600/1612117 instances
# Processed 117700/1612117 instances
# Processed 117800/1612117 instances
# Processed 117900/1612117 instances
# Processed 118000/1612117 instances
# Processed 118100/1612117 instances
# Processed 118200/1612117 instances
# Processed 118300/1612117 instances
# Processed 118400/1612117 instances
# Processed 118500/1612117 instances
# Processed 118600/1612117 instances
# Processed 118700/1612117 instances
# Processed 118800/1612117 instances
# Processed 118900/1612117 instances
# Processed 119000/1612117 instances
# Processed 119100/1612117 instances
# Processed 119200/1612117 instances
# Processed 119300/1612117 instances
# Processed 119400/1612117 instances
# Processed 119500/1612117 instances
# Processed 119600/1612117 instances
# Processed 119700/1612117 instances
# Processed 119800/1612117 instances
# Processed 119900/1612117 instances
# Processed 120000/1612117 instances
# Processed 120100/1612117 instances
# Processed 120200/1612117 instances
# Processed 120300/1612117 instances
# Processed 120400/1612117 instances
# Processed 120500/1612117 instances
# Processed 120600/1612117 instances
# Processed 120700/1612117 instances
# Processed 120800/1612117 instances
# Processed 120900/1612117 instances
# Processed 121000/1612117 instances
# Processed 121100/1612117 instances
# Processed 121200/1612117 instances
# Processed 121300/1612117 instances
# Processed 121400/1612117 instances
# Processed 121500/1612117 instances
# Processed 121600/1612117 instances
# Processed 121700/1612117 instances
# Processed 121800/1612117 instances
# Processed 121900/1612117 instances
# Processed 122000/1612117 instances
# Processed 122100/1612117 instances
# Processed 122200/1612117 instances
# Processed 122300/1612117 instances
# Processed 122400/1612117 instances
# Processed 122500/1612117 instances
# Processed 122600/1612117 instances
# Processed 122700/1612117 instances
# Processed 122800/1612117 instances
# Processed 122900/1612117 instances
# Processed 123000/1612117 instances
# Processed 123100/1612117 instances
# Processed 123200/1612117 instances
# Processed 123300/1612117 instances
# Processed 123400/1612117 instances
# Processed 123500/1612117 instances
# Processed 123600/1612117 instances
# Processed 123700/1612117 instances
# Processed 123800/1612117 instances
# Processed 123900/1612117 instances
# Processed 124000/1612117 instances
# Processed 124100/1612117 instances
# Processed 124200/1612117 instances
# Processed 124300/1612117 instances
# Processed 124400/1612117 instances
# Processed 124500/1612117 instances
# Processed 124600/1612117 instances
# Processed 124700/1612117 instances
# Processed 124800/1612117 instances
# Processed 124900/1612117 instances
# Processed 125000/1612117 instances
# Processed 125100/1612117 instances
# Processed 125200/1612117 instances
# Processed 125300/1612117 instances
# Processed 125400/1612117 instances
# Processed 125500/1612117 instances
# Processed 125600/1612117 instances
# Processed 125700/1612117 instances
# Processed 125800/1612117 instances
# Processed 125900/1612117 instances
# Processed 126000/1612117 instances
# Processed 126100/1612117 instances
# Processed 126200/1612117 instances
# Processed 126300/1612117 instances
# Processed 126400/1612117 instances
# Processed 126500/1612117 instances
# Processed 126600/1612117 instances
# Processed 126700/1612117 instances
# Processed 126800/1612117 instances
# Processed 126900/1612117 instances
# Processed 127000/1612117 instances
# Processed 127100/1612117 instances
# Processed 127200/1612117 instances
# Processed 127300/1612117 instances
# Processed 127400/1612117 instances
# Processed 127500/1612117 instances
# Processed 127600/1612117 instances
# Processed 127700/1612117 instances
# Processed 127800/1612117 instances
# Processed 127900/1612117 instances
# Processed 128000/1612117 instances
# Processed 128100/1612117 instances
# Processed 128200/1612117 instances
# Processed 128300/1612117 instances
# Processed 128400/1612117 instances
# Processed 128500/1612117 instances
# Processed 128600/1612117 instances
# Processed 128700/1612117 instances
# Processed 128800/1612117 instances
# Processed 128900/1612117 instances
# Processed 129000/1612117 instances
# Processed 129100/1612117 instances
# Processed 129200/1612117 instances
# Processed 129300/1612117 instances
# Processed 129400/1612117 instances
# Processed 129500/1612117 instances
# Processed 129600/1612117 instances
# Processed 129700/1612117 instances
# Processed 129800/1612117 instances
# Processed 129900/1612117 instances
# Processed 130000/1612117 instances
# Processed 130100/1612117 instances
# Processed 130200/1612117 instances
# Processed 130300/1612117 instances
# Processed 130400/1612117 instances
# Processed 130500/1612117 instances
# Processed 130600/1612117 instances
# Processed 130700/1612117 instances
# Processed 130800/1612117 instances
# Processed 130900/1612117 instances
# Processed 131000/1612117 instances
# Processed 131100/1612117 instances
# Processed 131200/1612117 instances
# Processed 131300/1612117 instances
# Processed 131400/1612117 instances
# Processed 131500/1612117 instances
# Processed 131600/1612117 instances
# Processed 131700/1612117 instances
# Processed 131800/1612117 instances
# Processed 131900/1612117 instances
# Processed 132000/1612117 instances
# Processed 132100/1612117 instances
# Processed 132200/1612117 instances
# Processed 132300/1612117 instances
# Processed 132400/1612117 instances
# Processed 132500/1612117 instances
# Processed 132600/1612117 instances
# Processed 132700/1612117 instances
# Processed 132800/1612117 instances
# Processed 132900/1612117 instances
# Processed 133000/1612117 instances
# Processed 133100/1612117 instances
# Processed 133200/1612117 instances
# Processed 133300/1612117 instances
# Processed 133400/1612117 instances
# Processed 133500/1612117 instances
# Processed 133600/1612117 instances
# Processed 133700/1612117 instances
# Processed 133800/1612117 instances
# Processed 133900/1612117 instances
# Processed 134000/1612117 instances
# Processed 134100/1612117 instances
# Processed 134200/1612117 instances
# Processed 134300/1612117 instances
# Processed 134400/1612117 instances
# Processed 134500/1612117 instances
# Processed 134600/1612117 instances
# Processed 134700/1612117 instances
# Processed 134800/1612117 instances
# Processed 134900/1612117 instances
# Processed 135000/1612117 instances
# Processed 135100/1612117 instances
# Processed 135200/1612117 instances
# Processed 135300/1612117 instances
# Processed 135400/1612117 instances
# Processed 135500/1612117 instances
# Processed 135600/1612117 instances
# Processed 135700/1612117 instances
# Processed 135800/1612117 instances
# Processed 135900/1612117 instances
# Processed 136000/1612117 instances
# Processed 136100/1612117 instances
# Processed 136200/1612117 instances
# Processed 136300/1612117 instances
# Processed 136400/1612117 instances
# Processed 136500/1612117 instances
# Processed 136600/1612117 instances
# Processed 136700/1612117 instances
# Processed 136800/1612117 instances
# Processed 136900/1612117 instances
# Processed 137000/1612117 instances
# Processed 137100/1612117 instances
# Processed 137200/1612117 instances
# Processed 137300/1612117 instances
# Processed 137400/1612117 instances
# Processed 137500/1612117 instances
# Processed 137600/1612117 instances
# Processed 137700/1612117 instances
# Processed 137800/1612117 instances
# Processed 137900/1612117 instances
# Processed 138000/1612117 instances
# Processed 138100/1612117 instances
# Processed 138200/1612117 instances
# Processed 138300/1612117 instances
# Processed 138400/1612117 instances
# Processed 138500/1612117 instances
# Processed 138600/1612117 instances
# Processed 138700/1612117 instances
# Processed 138800/1612117 instances
# Processed 138900/1612117 instances
# Processed 139000/1612117 instances
# Processed 139100/1612117 instances
# Processed 139200/1612117 instances
# Processed 139300/1612117 instances
# Processed 139400/1612117 instances
# ...
# Processed 1567800/1612117 instances
# Processed 1567900/1612117 instances
# Processed 1568000/1612117 instances
# Processed 1568100/1612117 instances
# Processed 1568200/1612117 instances
# Processed 1568300/1612117 instances
# Processed 1568400/1612117 instances
# Processed 1568500/1612117 instances
# Processed 1568600/1612117 instances
# Processed 1568700/1612117 instances
# Processed 1568800/1612117 instances
# Processed 1568900/1612117 instances
# Processed 1569000/1612117 instances
# Processed 1569100/1612117 instances
# Processed 1569200/1612117 instances
# Processed 1569300/1612117 instances
# Processed 1569400/1612117 instances
# Processed 1569500/1612117 instances
# Processed 1569600/1612117 instances
# Processed 1569700/1612117 instances
# Processed 1569800/1612117 instances
# Processed 1569900/1612117 instances
# Processed 1570000/1612117 instances
# Processed 1570100/1612117 instances
# Processed 1570200/1612117 instances
# Processed 1570300/1612117 instances
# Processed 1570400/1612117 instances
# Processed 1570500/1612117 instances
# Processed 1570600/1612117 instances
# Processed 1570700/1612117 instances
# Processed 1570800/1612117 instances
# Processed 1570900/1612117 instances
# Processed 1571000/1612117 instances
# Processed 1571100/1612117 instances
# Processed 1571200/1612117 instances
# Processed 1571300/1612117 instances
# Processed 1571400/1612117 instances
# Processed 1571500/1612117 instances
# Processed 1571600/1612117 instances
# Processed 1571700/1612117 instances
# Processed 1571800/1612117 instances
# Processed 1571900/1612117 instances
# Processed 1572000/1612117 instances
# Processed 1572100/1612117 instances
# Processed 1572200/1612117 instances
# Processed 1572300/1612117 instances
# Processed 1572400/1612117 instances
# Processed 1572500/1612117 instances
# Processed 1572600/1612117 instances
# Processed 1572700/1612117 instances
# Processed 1572800/1612117 instances
# Processed 1572900/1612117 instances
# Processed 1573000/1612117 instances
# Processed 1573100/1612117 instances
# Processed 1573200/1612117 instances
# Processed 1573300/1612117 instances
# Processed 1573400/1612117 instances
# Processed 1573500/1612117 instances
# Processed 1573600/1612117 instances
# Processed 1573700/1612117 instances
# Processed 1573800/1612117 instances
# Processed 1573900/1612117 instances
# Processed 1574000/1612117 instances
# Processed 1574100/1612117 instances
# Processed 1574200/1612117 instances
# Processed 1574300/1612117 instances
# Processed 1574400/1612117 instances
# Processed 1574500/1612117 instances
# Processed 1574600/1612117 instances
# Processed 1574700/1612117 instances
# Processed 1574800/1612117 instances
# Processed 1574900/1612117 instances
# Processed 1575000/1612117 instances
# Processed 1575100/1612117 instances
# Processed 1575200/1612117 instances
# Processed 1575300/1612117 instances
# Processed 1575400/1612117 instances
# Processed 1575500/1612117 instances
# Processed 1575600/1612117 instances
# Processed 1575700/1612117 instances
# Processed 1575800/1612117 instances
# Processed 1575900/1612117 instances
# Processed 1576000/1612117 instances
# Processed 1576100/1612117 instances
# Processed 1576200/1612117 instances
# Processed 1576300/1612117 instances
# Processed 1576400/1612117 instances
# Processed 1576500/1612117 instances
# Processed 1576600/1612117 instances
# Processed 1576700/1612117 instances
# Processed 1576800/1612117 instances
# Processed 1576900/1612117 instances
# Processed 1577000/1612117 instances
# Processed 1577100/1612117 instances
# Processed 1577200/1612117 instances
# Processed 1577300/1612117 instances
# Processed 1577400/1612117 instances
# Processed 1577500/1612117 instances
# Processed 1577600/1612117 instances
# Processed 1577700/1612117 instances
# Processed 1577800/1612117 instances
# Processed 1577900/1612117 instances
# Processed 1578000/1612117 instances
# Processed 1578100/1612117 instances
# Processed 1578200/1612117 instances
# Processed 1578300/1612117 instances
# Processed 1578400/1612117 instances
# Processed 1578500/1612117 instances
# Processed 1578600/1612117 instances
# Processed 1578700/1612117 instances
# Processed 1578800/1612117 instances
# Processed 1578900/1612117 instances
# Processed 1579000/1612117 instances
# Processed 1579100/1612117 instances
# Processed 1579200/1612117 instances
# Processed 1579300/1612117 instances
# Processed 1579400/1612117 instances
# Processed 1579500/1612117 instances
# Processed 1579600/1612117 instances
# Processed 1579700/1612117 instances
# Processed 1579800/1612117 instances
# Processed 1579900/1612117 instances
# Processed 1580000/1612117 instances
# Processed 1580100/1612117 instances
# Processed 1580200/1612117 instances
# Processed 1580300/1612117 instances
# Processed 1580400/1612117 instances
# Processed 1580500/1612117 instances
# Processed 1580600/1612117 instances
# Processed 1580700/1612117 instances
# Processed 1580800/1612117 instances
# Processed 1580900/1612117 instances
# Processed 1581000/1612117 instances
# Processed 1581100/1612117 instances
# Processed 1581200/1612117 instances
# Processed 1581300/1612117 instances
# Processed 1581400/1612117 instances
# Processed 1581500/1612117 instances
# Processed 1581600/1612117 instances
# Processed 1581700/1612117 instances
# Processed 1581800/1612117 instances
# Processed 1581900/1612117 instances
# Processed 1582000/1612117 instances
# Processed 1582100/1612117 instances
# Processed 1582200/1612117 instances
# Processed 1582300/1612117 instances
# Processed 1582400/1612117 instances
# Processed 1582500/1612117 instances
# Processed 1582600/1612117 instances
# Processed 1582700/1612117 instances
# Processed 1582800/1612117 instances
# Processed 1582900/1612117 instances
# Processed 1583000/1612117 instances
# Processed 1583100/1612117 instances
# Processed 1583200/1612117 instances
# Processed 1583300/1612117 instances
# Processed 1583400/1612117 instances
# Processed 1583500/1612117 instances
# Processed 1583600/1612117 instances
# Processed 1583700/1612117 instances
# Processed 1583800/1612117 instances
# Processed 1583900/1612117 instances
# Processed 1584000/1612117 instances
# Processed 1584100/1612117 instances
# Processed 1584200/1612117 instances
# Processed 1584300/1612117 instances
# Processed 1584400/1612117 instances
# Processed 1584500/1612117 instances
# Processed 1584600/1612117 instances
# Processed 1584700/1612117 instances
# Processed 1584800/1612117 instances
# Processed 1584900/1612117 instances
# Processed 1585000/1612117 instances
# Processed 1585100/1612117 instances
# Processed 1585200/1612117 instances
# Processed 1585300/1612117 instances
# Processed 1585400/1612117 instances
# Processed 1585500/1612117 instances
# Processed 1585600/1612117 instances
# Processed 1585700/1612117 instances
# Processed 1585800/1612117 instances
# Processed 1585900/1612117 instances
# Processed 1586000/1612117 instances
# Processed 1586100/1612117 instances
# Processed 1586200/1612117 instances
# Processed 1586300/1612117 instances
# Processed 1586400/1612117 instances
# Processed 1586500/1612117 instances
# Processed 1586600/1612117 instances
# Processed 1586700/1612117 instances
# Processed 1586800/1612117 instances
# Processed 1586900/1612117 instances
# Processed 1587000/1612117 instances
# Processed 1587100/1612117 instances
# Processed 1587200/1612117 instances
# Processed 1587300/1612117 instances
# Processed 1587400/1612117 instances
# Processed 1587500/1612117 instances
# Processed 1587600/1612117 instances
# Processed 1587700/1612117 instances
# Processed 1587800/1612117 instances
# Processed 1587900/1612117 instances
# Processed 1588000/1612117 instances
# Processed 1588100/1612117 instances
# Processed 1588200/1612117 instances
# Processed 1588300/1612117 instances
# Processed 1588400/1612117 instances
# Processed 1588500/1612117 instances
# Processed 1588600/1612117 instances
# Processed 1588700/1612117 instances
# Processed 1588800/1612117 instances
# Processed 1588900/1612117 instances
# Processed 1589000/1612117 instances
# Processed 1589100/1612117 instances
# Processed 1589200/1612117 instances
# Processed 1589300/1612117 instances
# Processed 1589400/1612117 instances
# Processed 1589500/1612117 instances
# Processed 1589600/1612117 instances
# Processed 1589700/1612117 instances
# Processed 1589800/1612117 instances
# Processed 1589900/1612117 instances
# Processed 1590000/1612117 instances
# Processed 1590100/1612117 instances
# Processed 1590200/1612117 instances
# Processed 1590300/1612117 instances
# Processed 1590400/1612117 instances
# Processed 1590500/1612117 instances
# Processed 1590600/1612117 instances
# Processed 1590700/1612117 instances
# Processed 1590800/1612117 instances
# Processed 1590900/1612117 instances
# Processed 1591000/1612117 instances
# Processed 1591100/1612117 instances
# Processed 1591200/1612117 instances
# Processed 1591300/1612117 instances
# Processed 1591400/1612117 instances
# Processed 1591500/1612117 instances
# Processed 1591600/1612117 instances
# Processed 1591700/1612117 instances
# Processed 1591800/1612117 instances
# Processed 1591900/1612117 instances
# Processed 1592000/1612117 instances
# Processed 1592100/1612117 instances
# Processed 1592200/1612117 instances
# Processed 1592300/1612117 instances
# Processed 1592400/1612117 instances
# Processed 1592500/1612117 instances
# Processed 1592600/1612117 instances
# Processed 1592700/1612117 instances
# Processed 1592800/1612117 instances
# Processed 1592900/1612117 instances
# Processed 1593000/1612117 instances
# Processed 1593100/1612117 instances
# Processed 1593200/1612117 instances
# Processed 1593300/1612117 instances
# Processed 1593400/1612117 instances
# Processed 1593500/1612117 instances
# Processed 1593600/1612117 instances
# Processed 1593700/1612117 instances
# Processed 1593800/1612117 instances
# Processed 1593900/1612117 instances
# Processed 1594000/1612117 instances
# Processed 1594100/1612117 instances
# Processed 1594200/1612117 instances
# Processed 1594300/1612117 instances
# Processed 1594400/1612117 instances
# Processed 1594500/1612117 instances
# Processed 1594600/1612117 instances
# Processed 1594700/1612117 instances
# Processed 1594800/1612117 instances
# Processed 1594900/1612117 instances
# Processed 1595000/1612117 instances
# Processed 1595100/1612117 instances
# Processed 1595200/1612117 instances
# Processed 1595300/1612117 instances
# Processed 1595400/1612117 instances
# Processed 1595500/1612117 instances
# Processed 1595600/1612117 instances
# Processed 1595700/1612117 instances
# Processed 1595800/1612117 instances
# Processed 1595900/1612117 instances
# Processed 1596000/1612117 instances
# Processed 1596100/1612117 instances
# Processed 1596200/1612117 instances
# Processed 1596300/1612117 instances
# Processed 1596400/1612117 instances
# Processed 1596500/1612117 instances
# Processed 1596600/1612117 instances
# Processed 1596700/1612117 instances
# Processed 1596800/1612117 instances
# Processed 1596900/1612117 instances
# Processed 1597000/1612117 instances
# Processed 1597100/1612117 instances
# Processed 1597200/1612117 instances
# Processed 1597300/1612117 instances
# Processed 1597400/1612117 instances
# Processed 1597500/1612117 instances
# Processed 1597600/1612117 instances
# Processed 1597700/1612117 instances
# Processed 1597800/1612117 instances
# Processed 1597900/1612117 instances
# Processed 1598000/1612117 instances
# Processed 1598100/1612117 instances
# Processed 1598200/1612117 instances
# Processed 1598300/1612117 instances
# Processed 1598400/1612117 instances
# Processed 1598500/1612117 instances
# Processed 1598600/1612117 instances
# Processed 1598700/1612117 instances
# Processed 1598800/1612117 instances
# Processed 1598900/1612117 instances
# Processed 1599000/1612117 instances
# Processed 1599100/1612117 instances
# Processed 1599200/1612117 instances
# Processed 1599300/1612117 instances
# Processed 1599400/1612117 instances
# Processed 1599500/1612117 instances
# Processed 1599600/1612117 instances
# Processed 1599700/1612117 instances
# Processed 1599800/1612117 instances
# Processed 1599900/1612117 instances
# Processed 1600000/1612117 instances
# Processed 1600100/1612117 instances
# Processed 1600200/1612117 instances
# Processed 1600300/1612117 instances
# Processed 1600400/1612117 instances
# Processed 1600500/1612117 instances
# Processed 1600600/1612117 instances
# Processed 1600700/1612117 instances
# Processed 1600800/1612117 instances
# Processed 1600900/1612117 instances
# Processed 1601000/1612117 instances
# Processed 1601100/1612117 instances
# Processed 1601200/1612117 instances
# Processed 1601300/1612117 instances
# Processed 1601400/1612117 instances
# Processed 1601500/1612117 instances
# Processed 1601600/1612117 instances
# Processed 1601700/1612117 instances
# Processed 1601800/1612117 instances
# Processed 1601900/1612117 instances
# Processed 1602000/1612117 instances
# Processed 1602100/1612117 instances
# Processed 1602200/1612117 instances
# Processed 1602300/1612117 instances
# Processed 1602400/1612117 instances
# Processed 1602500/1612117 instances
# Processed 1602600/1612117 instances
# Processed 1602700/1612117 instances
# Processed 1602800/1612117 instances
# Processed 1602900/1612117 instances
# Processed 1603000/1612117 instances
# Processed 1603100/1612117 instances
# Processed 1603200/1612117 instances
# Processed 1603300/1612117 instances
# Processed 1603400/1612117 instances
# Processed 1603500/1612117 instances
# Processed 1603600/1612117 instances
# Processed 1603700/1612117 instances
# Processed 1603800/1612117 instances
# Processed 1603900/1612117 instances
# Processed 1604000/1612117 instances
# Processed 1604100/1612117 instances
# Processed 1604200/1612117 instances
# Processed 1604300/1612117 instances
# Processed 1604400/1612117 instances
# Processed 1604500/1612117 instances
# Processed 1604600/1612117 instances
# Processed 1604700/1612117 instances
# Processed 1604800/1612117 instances
# Processed 1604900/1612117 instances
# Processed 1605000/1612117 instances
# Processed 1605100/1612117 instances
# Processed 1605200/1612117 instances
# Processed 1605300/1612117 instances
# Processed 1605400/1612117 instances
# Processed 1605500/1612117 instances
# Processed 1605600/1612117 instances
# Processed 1605700/1612117 instances
# Processed 1605800/1612117 instances
# Processed 1605900/1612117 instances
# Processed 1606000/1612117 instances
# Processed 1606100/1612117 instances
# Processed 1606200/1612117 instances
# Processed 1606300/1612117 instances
# Processed 1606400/1612117 instances
# Processed 1606500/1612117 instances
# Processed 1606600/1612117 instances
# Processed 1606700/1612117 instances
# Processed 1606800/1612117 instances
# Processed 1606900/1612117 instances
# Processed 1607000/1612117 instances
# Processed 1607100/1612117 instances
# Processed 1607200/1612117 instances
# Processed 1607300/1612117 instances
# Processed 1607400/1612117 instances
# Processed 1607500/1612117 instances
# Processed 1607600/1612117 instances
# Processed 1607700/1612117 instances
# Processed 1607800/1612117 instances
# Processed 1607900/1612117 instances
# Processed 1608000/1612117 instances
# Processed 1608100/1612117 instances
# Processed 1608200/1612117 instances
# Processed 1608300/1612117 instances
# Processed 1608400/1612117 instances
# Processed 1608500/1612117 instances
# Processed 1608600/1612117 instances
# Processed 1608700/1612117 instances
# Processed 1608800/1612117 instances
# Processed 1608900/1612117 instances
# Processed 1609000/1612117 instances
# Processed 1609100/1612117 instances
# Processed 1609200/1612117 instances
# Processed 1609300/1612117 instances
# Processed 1609400/1612117 instances
# Processed 1609500/1612117 instances
# Processed 1609600/1612117 instances
# Processed 1609700/1612117 instances
# Processed 1609800/1612117 instances
# Processed 1609900/1612117 instances
# Processed 1610000/1612117 instances
# Processed 1610100/1612117 instances
# Processed 1610200/1612117 instances
# Processed 1610300/1612117 instances
# Processed 1610400/1612117 instances
# Processed 1610500/1612117 instances
# Processed 1610600/1612117 instances
# Processed 1610700/1612117 instances
# Processed 1610800/1612117 instances
# Processed 1610900/1612117 instances
# Processed 1611000/1612117 instances
# Processed 1611100/1612117 instances
# Processed 1611200/1612117 instances
# Processed 1611300/1612117 instances
# Processed 1611400/1612117 instances
# Processed 1611500/1612117 instances
# Processed 1611600/1612117 instances
# Processed 1611700/1612117 instances
# Processed 1611800/1612117 instances
# Processed 1611900/1612117 instances
# Processed 1612000/1612117 instances
# Processed 1612100/1612117 instances

# %%
print(f"Total Execution Time: {end_time - start_time:.2f} seconds")
print(f"Total time spent on drift detection: {drift_time_total:.2f} seconds")
print(f"Total time spent updating metrics: {metrics_time_total:.2f} seconds")
print(f"Total drifts detected: {len(drift_events)}")
# Out:
# Total Execution Time: 12895.26 seconds
# Total time spent on drift detection: 5.28 seconds
# Total time spent updating metrics: 7.51 seconds
# Total drifts detected: 5

# %%
instances_processed = list(range(1, len(metric_logs['accuracy']) + 1))

# Create a plot
plt.figure(figsize=(6, 4))
plt.plot(instances_processed, metric_logs['accuracy'], label='Accuracy')
plt.plot(instances_processed, metric_logs['precision'], label='Precision', linestyle=':')
plt.plot(instances_processed, metric_logs['recall'], label='Recall', linestyle='--')
plt.plot(instances_processed, metric_logs['f1_score'], label='F1-Score', linestyle='-.')

# Add drift events without duplicating the label
for i, drift_event in enumerate(drift_events):
    plt.axvline(x=drift_event, color='blue', linestyle=':', linewidth=1, label='Drift Event' if i == 0 else "")

# Add labels, title, grid, and legend
plt.xlabel('Instances Processed')
plt.ylabel('Metric Value')
#plt.title('Performance Metrics Over Time')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend(loc='best')

# Save or show the plot
plt.savefig('PM6-1.png', dpi=1000, bbox_inches='tight')
plt.tight_layout()
plt.show()

# %%
instances_processed = list(range(1, len(metric_logs['accuracy']) + 1))

# Create a plot
plt.figure(figsize=(6, 4))
plt.plot(instances_processed, metric_logs['accuracy'], label='Accuracy')
plt.plot(instances_processed, metric_logs['precision'], label='Precision', linestyle=':')
plt.plot(instances_processed, metric_logs['recall'], label='Recall', linestyle='--')
plt.plot(instances_processed, metric_logs['f1_score'], label='F1-Score', linestyle='-.')

# Add drift events without duplicating the label
for i, drift_event in enumerate(drift_events):
    plt.axvline(x=drift_event, color='blue', linestyle=':', linewidth=1, label='Drift Event' if i == 0 else "")

# Add labels, title, grid, and legend
plt.xlabel('Instances Processed')
plt.ylabel('Metric Value')
#plt.title('Performance Metrics Over Time')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend(loc='best')

plt.xlim([0, 200])
plt.ylim([0, 0.8])

# Save or show the plot
plt.savefig('PM6-2.png', dpi=1000, bbox_inches='tight')
plt.tight_layout()
plt.show()

# %%
instances_processed = list(range(1, len(metric_logs['accuracy']) + 1))

# Create a plot
plt.figure(figsize=(6, 4))
plt.plot(instances_processed, metric_logs['accuracy'], label='Accuracy')
plt.plot(instances_processed, metric_logs['precision'], label='Precision', linestyle=':')
plt.plot(instances_processed, metric_logs['recall'], label='Recall', linestyle='--')
plt.plot(instances_processed, metric_logs['f1_score'], label='F1-Score', linestyle='-.')

# Add drift events without duplicating the label
for i, drift_event in enumerate(drift_events):
    plt.axvline(x=drift_event, color='blue', linestyle=':', linewidth=1, label='Drift Event' if i == 0 else "")

# Add labels, title, grid, and legend
plt.xlabel('Instances Processed')
plt.ylabel('Metric Value')
#plt.title('Performance Metrics Over Time')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend(loc='best')

plt.xlim([0, 1000])
plt.ylim([0, 0.8])

# Save or show the plot
plt.savefig('PM6-3.png', dpi=1000, bbox_inches='tight')
plt.tight_layout()
plt.show()

# %%
instances_processed = list(range(1, len(metric_logs['accuracy']) + 1))

# Create a plot
plt.figure(figsize=(6, 4))
plt.plot(instances_processed, metric_logs['accuracy'], label='Accuracy')
plt.plot(instances_processed, metric_logs['precision'], label='Precision', linestyle=':')
plt.plot(instances_processed, metric_logs['recall'], label='Recall', linestyle='--')
plt.plot(instances_processed, metric_logs['f1_score'], label='F1-Score', linestyle='-.')

# Add drift events without duplicating the label
for i, drift_event in enumerate(drift_events):
    plt.axvline(x=drift_event, color='blue', linestyle=':', linewidth=1, label='Drift Event' if i == 0 else "")

# Add labels, title, grid, and legend
plt.xlabel('Instances Processed')
plt.ylabel('Metric Value')
#plt.title('Performance Metrics Over Time')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend(loc='best')

plt.xlim([0, 5000])

# Save or show the plot
plt.savefig('PM6-4.png', dpi=1000, bbox_inches='tight')
plt.tight_layout()
plt.show()

# %%
# Compute descriptive statistics
mean_time = np.mean(processing_times)
median_time = np.median(processing_times)
std_dev_time = np.std(processing_times)
outlier_threshold = mean_time + 3 * std_dev_time  # Define outliers as 3 standard deviations above the mean
outlier_counts = sum(time > outlier_threshold for time in processing_times)

# Plot histogram
plt.figure(figsize=(12, 4))
counts, bins, bars = plt.hist(processing_times, bins=30, edgecolor='white', color='blue', alpha=0.7, label='Processing Times')

# Add vertical lines for statistics
plt.axvline(mean_time, color='red', linestyle='dashed', linewidth=1.5, label=f'Mean: {mean_time:.4f}s')
plt.axvline(median_time, color='orange', linestyle='dashed', linewidth=1.5, label=f'Median: {median_time:.4f}s')
plt.axvline(mean_time + std_dev_time, color='deeppink', linestyle='dotted', linewidth=1, label=f'+1 Std Dev: {mean_time + std_dev_time:.4f}s')
plt.axvline(mean_time - std_dev_time, color='deeppink', linestyle='dotted', linewidth=1, label=f'-1 Std Dev: {mean_time - std_dev_time:.4f}s')
plt.axvline(outlier_threshold, color='green', linestyle='dotted', linewidth=1.5, label=f'Outlier Threshold: {outlier_threshold:.4f}s')

# Add annotations to the histogram bars
for count, bin_edge in zip(counts, bins):
    if count > 0:  # Avoid clutter for empty bins
        plt.text(bin_edge + (bins[1] - bins[0]) / 2, count, f'{int(count)}', ha='center', va='bottom')

# Annotate outliers
plt.text(outlier_threshold, max(counts) * 0.8, f'{outlier_counts} outliers', color='green', ha='left')

# Add labels, legend, and title
plt.xlabel('Processing Time (seconds)')
plt.ylabel('Frequency')
#plt.title('Enhanced Distribution of Instance Processing Times')
# Add grid and legend
plt.grid(True, which='both', axis='y', linestyle='--', linewidth=0.5)
plt.legend()
plt.savefig('PT6.png', dpi=1000, bbox_inches='tight')

# Show the plot
plt.show()

# %%
# Calculate cumulative sums
cumulative_drift_time = np.cumsum(drift_time_per_instance)
cumulative_metrics_time = np.cumsum(metrics_time_per_instance)
cumulative_total_time = cumulative_drift_time + cumulative_metrics_time
processing_time = list(range(len(cumulative_drift_time)))

epsilon = 1e-10  # A small value to avoid division by zero

# Safely handle division by zero using NumPy
cumulative_total_time = np.where(cumulative_total_time == 0, epsilon, cumulative_total_time)

# Convert to percentages
cumulative_drift_percent = cumulative_drift_time / cumulative_total_time * 100
cumulative_metrics_percent = cumulative_metrics_time / cumulative_total_time * 100

# Create dual-axis plot
fig, ax1 = plt.subplots(figsize=(6, 4))

# Primary Y-Axis (percentages)
ax1.stackplot(processing_time, cumulative_drift_percent, cumulative_metrics_percent,
              labels=['Drift Detection (Percent)', 'Metrics Update (Percent)'],
              colors=['#FF9999', '#99CCFF'], alpha=0.8)
ax1.set_xlabel('Instances Processed')
ax1.set_ylabel('Cumulative Contribution (%)')
ax1.legend(loc='upper left')
ax1.grid(True, linestyle='--', linewidth=0.5)

# Secondary Y-Axis (total time)
ax2 = ax1.twinx()
ax2.plot(processing_time, cumulative_total_time, color='black', linestyle='--', linewidth=1, label='Total Cumulative Time')
ax2.set_ylabel('Total Cumulative Time (seconds)')
ax2.legend(loc='upper right')

# Annotate drift events
for i, drift_instance in enumerate(drift_events):
    ax1.axvline(drift_instance, color='blue', linestyle='dotted', linewidth=1)
    ax1.text(drift_instance, 2, f'Drift - {drift_instance}', rotation=90, color='blue')

# Add title and save
#plt.title('Enhanced Cumulative Time Analysis with Dual Y-Axis')
plt.tight_layout()
plt.savefig('CT6.png', dpi=1000, bbox_inches='tight')
plt.show()

# %%
if drift_events:
    # Extract pre-drift and post-drift accuracies for each drift event
    pre_drift_accuracy = [metric_logs['accuracy'][i-1] for i in drift_events]
    post_drift_accuracy = [metric_logs['accuracy'][i] for i in drift_events]
    drift_labels = [f'Drift {i+1}' for i in range(len(drift_events))]
    
    # Sort drift events by the magnitude of accuracy change
    sorted_indices = sorted(range(len(drift_events)), key=lambda i: abs(pre_drift_accuracy[i] - post_drift_accuracy[i]), reverse=True)
    pre_drift_accuracy = [pre_drift_accuracy[i] for i in sorted_indices]
    post_drift_accuracy = [post_drift_accuracy[i] for i in sorted_indices]
    drift_labels = [drift_labels[i] for i in sorted_indices]
    
    x = range(len(drift_events))  # X-axis positions for drift events

    # Set up the figure
    plt.figure(figsize=(6, 5))
    
    # Bar width for side-by-side comparison
    bar_width = 0.4
    
    # Plot pre-drift and post-drift accuracies
    plt.bar(x, pre_drift_accuracy, width=bar_width, label='Pre-Drift Accuracy', color='#1f77b4', alpha=0.8)
    plt.bar([i + bar_width for i in x], post_drift_accuracy, width=bar_width, label='Post-Drift Accuracy', color='#ff7f0e', alpha=0.8)
    
    # Annotate bars with their accuracy values
    for i, (pre, post) in enumerate(zip(pre_drift_accuracy, post_drift_accuracy)):
        plt.text(i, pre, f'{pre:.2f}', ha='center', va='bottom', color='black')
        plt.text(i + bar_width, post, f'{post:.2f}', ha='center', va='bottom', color='black')

        # Add percentage change annotation
        pct_change = ((post - pre) / pre) * 100 if pre > 0 else 0
        plt.text(i + bar_width / 2, max(pre, post) + 0.04, f'{pct_change:+.6f}%', ha='center', color='green' if pct_change > 0 else 'red')
    
    # Add descriptive x-axis labels for drift events
    plt.xticks([i + bar_width / 2 for i in x], drift_labels)

    # Calculate and plot the average accuracy as a horizontal line
    avg_accuracy = sum(metric_logs['accuracy']) / len(metric_logs['accuracy'])
    plt.axhline(avg_accuracy, color='red', linestyle='--', linewidth=1, label=f'Average Accuracy: {avg_accuracy:.2f}')

    # Add labels, title, grid, and legend
    plt.xlabel('Drift Event')
    plt.ylabel('Accuracy')
    #plt.title('Model Accuracy Before and After Drift (with Percentage Changes)')
    plt.ylim(0, 1.08)  # Adjust y-axis limits for better focus
    plt.grid(True, which='both', linestyle='--', linewidth=0.5)
    plt.legend(loc='lower right')
    plt.tight_layout()

    # Save the chart as a high-resolution image (optional)
    plt.savefig('MA6.png', dpi=1000, bbox_inches='tight')

    # Display the plot
    plt.show()
else:
    print("No drift events detected.")

# %%
# Initialize class distribution dictionary with cumulative sums
class_distribution = {cls: [0] for cls in set(y)}  # Start with 0 for all classes

# Update cumulative counts for each class
for i, cls in enumerate(y):
    for key in class_distribution:
        class_distribution[key].append(class_distribution[key][-1] + (1 if cls == key else 0))

# Remove the initial zero added to each class (optional for clarity)
for key in class_distribution:
    class_distribution[key] = class_distribution[key][1:]

plt.figure(figsize=(4, 4))
for cls, counts in class_distribution.items():
    plt.plot(instances_processed, counts, label=f'Class {cls}')
plt.xlabel('Instances Processed')
plt.ylabel('Class Distribution')
#plt.title('Class Distribution Over Time')
# Add grid and legend
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend(loc='best')
plt.savefig('CD6.png', dpi=1000, bbox_inches='tight')
plt.show()

# %%
# Smooth function
def smooth(data, window_size=50):
    return np.convolve(data, np.ones(window_size) / window_size, mode='same')

# Initialize class distribution dictionary
class_distribution = {cls: [] for cls in set(y)}

# Initialize running counter for each class
running_counts = Counter()

# Generate instances_processed to match the length of y
instances_processed = list(range(1, len(y) + 1))

# Calculate cumulative counts efficiently
for i, label in enumerate(y):
    running_counts[label] += 1  # Update count for the current label
    for cls in class_distribution.keys():
        class_distribution[cls].append(running_counts[cls])

# Normalize cumulative counts to proportions
total_instances = np.arange(1, len(y) + 1)  # Matches the length of instances_processed
normalized_distribution = {cls: np.array(counts) / total_instances for cls, counts in class_distribution.items()}

# Smooth the data
smoothed_distribution = {cls: smooth(proportions, window_size=50) for cls, proportions in normalized_distribution.items()}

# Plot class distribution over time (full view)
plt.figure(figsize=(5, 4))
for cls, proportions in smoothed_distribution.items():
    plt.plot(instances_processed, proportions, label=f'Class {cls}', linewidth=1, linestyle='--', alpha=0.8)
    
# Add drift markers
for drift_event in drift_events:
    plt.axvline(x=drift_event, color='blue', linestyle=':', linewidth=1, label='Drift Event' if drift_event == drift_events[0] else "")

# Add labels, title, grid, and legend
plt.xlabel('Instances Processed')
plt.ylabel('Class Proportion')
#plt.title('Smoothed Normalized Class Distribution Over Time with Drift Markers')
plt.grid(True, which='both', axis='y', linestyle='--', linewidth=0.5)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3)
plt.tight_layout()
plt.savefig('SD6.png', dpi=1000, bbox_inches='tight')
plt.show()

# %%
# Zoomed-in view for the first 100 instances
plt.figure(figsize=(5, 4))
for cls, proportions in smoothed_distribution.items():
    plt.plot(instances_processed[:100], proportions[:100], label=f'Class {cls}', linewidth=1, linestyle='--', alpha=0.8)

# Add drift markers (only for zoomed-in range)
for drift_event in drift_events:
    if drift_event <= 100:
        plt.axvline(x=drift_event, color='blue', linestyle=':', linewidth=1, label='Drift Event' if drift_event == drift_events[0] else "")

# Add labels, title, grid, and legend
plt.xlabel('Instances Processed (First 100)')
plt.ylabel('Class Proportion')
#plt.title('Zoomed-In Class Distribution (First 100 Instances) with Drift Markers')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3)
plt.tight_layout()
plt.savefig('ZD6-1.png', dpi=1000, bbox_inches='tight')
plt.show()

# %%
# Zoomed-in view for the last 100 instances
plt.figure(figsize=(5, 4))
for cls, proportions in smoothed_distribution.items():
    plt.plot(instances_processed[1612017:], proportions[1612017:], label=f'Class {cls}', linewidth=1, linestyle='--', alpha=0.8)

# Add drift markers (only for zoomed-in range)
for drift_event in drift_events:
    if drift_event >= 1612017:
        plt.axvline(x=drift_event, color='blue', linestyle=':', linewidth=1, label='Drift Event' if drift_event == drift_events[0] else "")

# Add labels, title, grid, and legend
plt.xlabel('Instances Processed (Last 100)')
plt.ylabel('Class Proportion')
#plt.title('Zoomed-In Class Distribution (Last 100 Instances) with Drift Markers')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3)
plt.tight_layout()
plt.savefig('ZD6-2.png', dpi=1000, bbox_inches='tight')
plt.show()

# %%
# Simulate feature importances as uniform values for demonstration purposes
feature_importances = np.random.uniform(0, 1, len(X.columns))  # Replace with your actual method if available
feature_names = X.columns  # Assuming X is your DataFrame with feature names

# Sort feature importances and corresponding feature names in descending order
sorted_indices = np.argsort(feature_importances)[::-1]
sorted_feature_importances = feature_importances[sorted_indices]
sorted_feature_names = feature_names[sorted_indices]

# Plot feature importances as a horizontal bar chart
plt.figure(figsize=(6, 8))
plt.barh(range(len(sorted_feature_importances)), sorted_feature_importances, color='green')
plt.yticks(range(len(sorted_feature_importances)), sorted_feature_names)
plt.xlabel('Importance')
#plt.title('Feature Importance (Sorted)')
plt.grid(True, which='both', axis='x', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.savefig('FI6.png', dpi=1000, bbox_inches='tight')
plt.show()

# %%
# Print Final Metrics
print(f"Accuracy: {metric_accuracy.get():.4f}")
print(f"Precision: {metric_precision.get():.4f}")
print(f"Recall: {metric_recall.get():.4f}")
print(f"F1-Score: {metric_f1.get():.4f}")
# Out:
# Accuracy: 0.9949
# Precision: 0.9950
# Recall: 0.9949
# F1-Score: 0.9949
